# %%
import caf.base as cb
import caf.tem as ct
import caf.toolkit as ctk
import pandas as pd
from pathlib import Path
from caf.tem import mdlfunction as fun

# %%
a = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\test\mts4.hdf")

# %%
a.aggregate(["p", "m", "tp"]).data
# Out:
# normits_id    1001001     1001002       1001003     1001004     1001005   \
# p m tp
# 4 1 1        82.898928  160.485614   2849.178830   98.315661   59.763053
#     2       187.541091  363.064372   6445.657637  222.418153  135.201125
#     3        53.259323  103.105739   1830.486121   63.163972   38.395428
#     4        13.500850   26.136552    464.014866   16.011606    9.732961
#     5        87.388730  169.177508   3003.490243  103.640433   62.999818
#     6        60.732639  117.573472   2087.338797   72.027102   43.783050
#   2 1         5.411316   10.475870    185.983185    6.417660    3.901097
#     2        10.267183   19.876436    352.875990   12.176574    7.401763
#     3         2.132397    4.128149     73.289020    2.528960    1.537276
#     4         0.342557    0.663163     11.773457    0.406263    0.246955
#     5         5.649921   10.937790    194.183881    6.700638    4.073111
#     6         1.928593    3.733600     66.284403    2.287254    1.390351
# ...

# %%
fun.mkdir(self.tem_fldr / self.ins_fldr)

# %%
ctk.BaseConfig()
# Out:
# BaseConfig()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #cb.DVector.load(Path(""))
# ----> 2 ct.inputs.HBProdInput(ctk.BaseConfig())
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given

# %%
cb.ZoningSystem(
    name="LSOA21",
    unique_zones=pd.DataFrame(), # A sorted numpy array of unique zone names for this zoning system.
    metadata=None
)

# %%
Path("C:/Users/uktjp008/Documents/Python Tasks/TfN NorMits/Process Runs/outputs/productions/hb")
Path("C:/Users/uktjp008/Documents/Python Tasks/TfN NorMits/Process Runs/NoTEM/NorMits Land Use - Final Outputs")
population_paths = {
    2002: Path()
}
#Path("F:/Deliverables/Land-Use/241123_Population rebase/02_Final Outputs") # I need to find this folder
'''population_paths:
            Dictionary of {year: population_data} pairs.
            HBProductionModel._target_col_dtypes['pop']'''
trip_rates_path = Path("C:/Users/uktjp008/Documents/Python Tasks/TfN NorMits/Process Runs/outputs/productions/hb/trip_rates")
mode_time_splits_path = Path("C:/Users/uktjp008/Documents/Python Tasks/TfN NorMits/Process Runs/outputs/productions/hb/mode_time_splits")
export_home = Path()
return_segmentation = cb.Segmentation
model_zoning = cb.ZoningSystem
process_count = 1

# %%
ct.production_models.HBProductionModel(
    population_paths, 
    trip_rates_path, 
    mode_time_splits_path,
    export_home,
    return_segmentation,
    model_zoning,
    process_count
)

# %%
import caf.tem as ct

# %%
ct.
