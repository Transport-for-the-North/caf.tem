# %%
import caf.tem as ct
from pathlib import Path
import caf.base as cb
#import caf.base as cb
#import caf.toolkit as ctk
#from caf.tem.attraction_models import TP_generate_attraction
#from pathlib import Path
#from caf.tem.attraction_models import AttractionModel_TP

# %%
tem = ct.TEMModel( # add tem segmentations here? # pure segmentation as well? - pure follows input of mts applied (i.e. traveller types?) - hard coded in utils read pop
    model_years=[2023],
    scenario=ct.Scenarios("Core"),
    output_zoning="normits",
    iteration_name="full-run",
    export_home=r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export",
    return_segmentation=["p", "aws", "soc", "ns_sec", "hh_type", "gender_3", "adult_nssec"]
    #add tem seg - from notem in nts processing. / pure seg opts. [hh_type, purpose, mode, period] - tem default. pure
)

# %%
dvec_fldr = Path(r"C:\Users\Spiral\Documents\Thomas Prince\(normitsefs) Transfer\TP_20250128-copy\tem_inputs")

HBProd = tem.HBProductionModel(
    population_paths={2023: dvec_fldr / "pop_2023.dvec"},
    trip_rates_path=dvec_fldr / "hb_trip_rates_production_dvector.dvec",
    mode_time_splits_path=dvec_fldr / "hb_mode_time_split_production_hb_fr.dvec") # Should this be hb_fr?

# %%
HBProd.run()
#tem.export_paths.hb_attraction.export_paths.pure_demand[2023]

# %%
HBAttr = tem.HBAttractionModel(trip_rates_paths={
        1: r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\hb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\hb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\hb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\hb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\hb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\hb_attraction_triprates_p8.dvec"
    },
    balance_production=False,
    emp_landuse_paths = {2023: r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Inputs\Land Use\employment\normits\Output E6.hdf"},
    hh_landuse_dirs = {2023: r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Inputs\Land Use\population\normits"},
    hh_landuse_prefix = "Output P14.1",
    hb_mts_path=r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\hb\mode_time_splits\hb_mode_time_split_attraction_hb_fr.dvec")

# %%
HBAttr.run()
# Out:
# C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\caf.base\src\caf\base\zoning.py:681: TranslationWarning: 20 tfn_at zones have splitting factors which don't sum to 1 (value totals may change during zone_translation), the maximum difference is 7.7e+02
#   warnings.warn(
# C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\caf.base\src\caf\base\zoning.py:681: TranslationWarning: 20 tfn_at zones have splitting factors which don't sum to 1 (value totals may change during zone_translation), the maximum difference is 7.7e+02
#   warnings.warn(
# C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\caf.base\src\caf\base\segmentation.py:342: SegmentationWarning: Read in level sic_2_digit is a subset of the segment. If this was not expected check the input segmentation.
#   warnings.warn(
# ...

# %%
NHBAttr = tem.NHBAttractionModel(trip_rates_paths={
        1: r"T:\ThomasPrince\nhb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\nhb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\nhb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\nhb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\nhb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\nhb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\nhb_attraction_triprates_p8.dvec"
    },
    balance_production=False,
    emp_landuse_paths = {2023: r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Inputs\Land Use\employment\normits\Output E6.hdf"},
    hh_landuse_dirs = {2023: r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Inputs\Land Use\population\normits"},
    hh_landuse_prefix = "Output P14.1",
    nhb_mts_path=r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\hb\mode_time_splits\nhb_mode_time_split_attraction_nhb_fr.dvec")

# %%
HBAttr.production_paths[2023]

# %%
seg1 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand1.hdf")
seg2 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand2.hdf")
seg3 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand3.hdf")
seg4 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand4.hdf")
seg5 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand5.hdf")
seg6 = cb.DVector.load(Path(HBAttr.model.export_home) / "seg_demand6.hdf")
seg8 = cb.DVector.load(Path(HBAttr.model.export_home) / "mts_demand8.hdf")
pd = cb.DVector.load(HBAttr.production_paths[2023])

# %%
for dvec in [seg1,  seg2, seg3,  seg4,  seg5, seg6, seg8]:
    print(dvec.segmentation.names)

# %%
pp = cb.DVector.load(HBAttr.production_model.export_paths.tem_segmented[2023])

# %%
bal1 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand1.hdf")
bal2 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand2.hdf")
bal3 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand3.hdf")
bal4 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand4.hdf")
bal5 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand5.hdf")
bal6 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand6.hdf")
bal8 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\full-run\Core\hb_attractions\bal_demand8.hdf")

# %%
print(bal1.segmentation.names)
print(bal2.segmentation.names)
print(bal3.segmentation.names)
print(bal4.segmentation.names)
print(bal5.segmentation.names)
print(bal6.segmentation.names)
print(bal8.segmentation.names)

# %%
input = cb.segmentation.SegmentationInput(enum_segments=['aws', 'adult_nssec', 'tp', 'ns_sec', 'hh_type', 'm', 'gender_3', 'soc', 'p'], 
                                  naming_order=['aws', 'adult_nssec', 'tp', 'ns_sec', 'hh_type', 'm', 'gender_3', 'soc', 'p'])

seg = cb.Segmentation(input)

# %%
bal1.remove_zoning().data#concat(bal3).data
# Out:
# soc  p  m  tp  adult_nssec  gender_3  ns_sec  aws  hh_type
# 1    1  1  1   1            2         1       2    1          8.461567e+05
#                                                    2          1.740808e+06
#                                               3    1          2.833918e+04
#                                                    2          5.942668e+04
#                             3         1       2    1          5.286876e+05
#                                                                   ...
# 4    1  7  6   15           3         5       5    7          4.327963e+03
#                                                    8          4.580462e+03
#                                               6    6          1.444295e+02
#                                                    7          2.676370e+02
#                                                    8          2.218327e+02
# Name: val, Length: 29904, dtype: float64

# %%
bal1.concat(bal3.aggregate(bal1.segmentation, _bypass_validation=True)).data

# %%
bal3.aggregate(bal1.segmentation, _bypass_validation=True).data

# %%
bal3.aggregate(bal1.segmentation).data

# %%
bal3.data

# %%
bal3.concat(bal4).concat(bal5).concat(bal6).concat(bal8)

# %%
bal3.data.reset_index().p.unique()
bal1.data.reset_index().p.unique()#'segmentation.names

# %%
bal2._segmentation

# %%
bal1.aggregate(seg).data

# %%
bal3.aggregate(seg).data

# %%
temp = bal1.segmentation.names#.remove("soc") 
test = temp.sort("p")

# %%
tem.export_paths.hb_attraction.report_paths.

# %%
bal1.concat(bal2).concat(bal3.aggregate(bal3.segmentation.names.remove("total")))

# %%
bal3.translate_zoning(bal3.zoning_system, check_totals=False, no_factors=True)# .data#.segmentation.names #+ bal4

# %%
bal4.segmentation.remove_segment().segmentation.names

# %%
bal3.translate_zoning(cb.ZoningSystem.get_zoning("gor")).aggregate(["p", "m", "tp"]).data

# %%
seg3.data

# %%
seg1.data

# %%
seg6.split_by_other(pp.filter_segment_value("p", [6]), agg_zone=cb.ZoningSystem.get_zoning("gor")).data

# %%
mts_ = mts6.aggregate(["soc", "p", "m"])
mts_.data

# %%
pd.data

# %%
cb.ZoningSystem.get_zoning("gor").zones_data

# %%
translation = pd.zoning_system.translate(cb.ZoningSystem.get_zoning("gor"))
translation

# %%
mts_.data

# %%
pd.data

# %%
translation

# %%
mts.data

# %%
mts_.split_by_other(pd.filter_segment_value("p", [1]), cb.ZoningSystem.get_zoning("gor")).data

# %%
cb.ZoningSystem.get_zoning("gor").name

# %%
mts_.zoning_system.translate()

# %%
prod = cb.DVector.load(HBProd.model.export_paths.tem_segmented[2023])
prod.data

# %%
list(mts_.segmentation.overlap(pd.segmentation))

# %%
pd.data.groupby(level={"p", "aws"}).sum()

# %%
mts = cb.DVector.load(HBAttr.mts_path)

# %%
mts_ = mts.add_segments([cb.segmentation.SegmentsSuper("soc").get_segment(subset=[1])]).filter_segment_value("p", [1])#.data#.data.head(80).style

# %%
a = mts * mts_

# %%
a.data

# %%
cb.Segmentation(cb.SegmentationInput(enum_segments=["soc"], naming_order=["soc"]))

# %%
HBProd.export_paths.export_paths.tem_segmented[2023]

# %%
HBattr = tem.HBAttractionModel(trip_rates_paths={
        1: r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\hb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\hb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\hb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\hb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\hb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\hb_attraction_triprates_p8.dvec"
    },
    balance_production=False,
    emp_landuse_paths = {2023: r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf"},
    hh_landuse_dirs = {2023: r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs"},
    hh_landuse_prefix = "Output P14.1",
    hb_mts_split_path=r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\hb\mode_time_splits\hb_mode_time_split_attraction_hb_fr.dvec")

# %%
pure_demand = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP_v2\Core\hb_attractions\hb_normits_pure_demand_2023_dvec.h5")

# %%
pure_demand.data

# %%
pure_production = cb.DVector.load(HBProd.trip_rates_path)

# %%
pure_production.data

# %%
HBProd.trip_rates_path

# %%
pure_production.data

# %%
p4 = cb.DVector.load(r"T:\ThomasPrince\hb_attraction_triprates_p4.dvec")

# %%
p4.data

# %%
no_zone = p4.remove_zoning()#.data#.translate_zoning(cb.ZoningSystem.get_zoning("gb"))

# %%
no_zone.data

# %%
(p4 * no_zone).data

# %%
#.translate_zoning(cb.ZoningSystem.get_zoning("lsoa_2021"))

# %%
cb.segmentation.SegmentsSuper("soc").get_segment()

# %%
p4 = p4.add_segments([cb.segmentation.SegmentsSuper("total").get_segment()], split_method="split")

# %%
p4_ = p4.aggregate(["total"]).add_segments(["soc"], split_method="split")#.data

# %%
p4.data

# %%
p4_.data

# %%
(p4_+p4).data

# %%
import pandas as pd
soc = pd.Series(data = [1], name="soc", index = ["sic_2_digit"])

# %%
p4_.data

# %%
p4_.add_segments([cb.segmentation.SegmentsSuper("soc").get_segment()], None, "split", None).data

# %%
# employment data to sub categories

# %%
emp = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Land Use\employment\Output E6 - lsoa_2021.hdf")

# %%
emp.translate_zoning(cb.ZoningSystem.get_zoning("normits")).aggregate(["soc", "sic_2_digit"]).data

# %%
emp.translate_zoning(cb.ZoningSystem.get_zoning("lsoa_2021"))

# %%
temp = emp.data.reset_index()

# %%
temp.loc[temp["sic_2_digit"].isin([46,47])]

# %%
p4.data

# %%
HBattr.run()

# %%
test = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP_v2\Core\hb_attractions\hb_normits_tem_segmented_2023_dvec.h5")

# %%
test2 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP_v4\Core\hb_attractions\hb_normits_tem_segmented_2023_dvec.h5")

# %%
test2.data#.sum(axis=1)

# %%
test.sum()

# %%
test2 = test.aggregate(["soc", "p", "m", "tp"])

# %%
check = test2.data

# %%
cb.segmentation.SegmentsSuper("p").get_segment()

# %%
check.index==(1*)#[1]

# %%
#check = check.reset_index()
check.loc[(check["soc"]==4) & (check["p"]==1)]#.sum()#.unique()

# %%
NHBattr = tem.NHBAttractionModel(trip_rates_paths={
        1: r"T:\ThomasPrince\nhb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\nhb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\nhb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\nhb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\nhb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\nhb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\nhb_attraction_triprates_p8.dvec"
    },
    emp_landuse_paths = {2023: r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf"},
    hh_landuse_dirs = {2023: r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs"},
    hh_landuse_prefix = "Output P14.1",
    nhb_mts_split_path=r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\nhb\mode_time_splits\hb_mode_time_split_attraction.dvec")

# %%
hb_mts = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\hb\mode_time_splits\hb_mode_time_split_attraction_hb_fr.dvec")
hb_mts = hb_mts.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
hb_mts = hb_mts.filter_segment_value("p", [1])
hb_mts.data

# %%
cb.DVector.concat([])

# %%
hbattr = cb.DVector.load(HBattr.export_paths.export_paths.pure_demand[2023])
hbattr = hbattr.filter_segment_value("p", [1])
hbattr.data

# %%
other.concat(other=hbattr)

# %%
cb.segmentation.SegmentsSuper("ns_sec").get_segment()

# %%
cb.segmentation.Segmentation.

# %%
(hbattr * hb_mts).data # hbproduction applies mts and filters also - check code - employment segmentation, trust user? Pure attraction segmentation?

# %%
(hb_mts * hbattr).data

# %%
hb_mts.__mul__()

# %%
cb.segmentation.SegmentsSuper("m").get_segment()

# %%
aa = cb.DVector.load(r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs\Output P13.3_NE.hdf")

# %%
aa.data

# %%
p1 = cb.DVector.load(HBattr.trip_rates_paths[1])
p2 = cb.DVector.load(HBattr.trip_rates_paths[2])
p3 = cb.DVector.load(HBattr.trip_rates_paths[3])
p4 = cb.DVector.load(HBattr.trip_rates_paths[4])
p5 = cb.DVector.load(HBattr.trip_rates_paths[5])
p6 = cb.DVector.load(HBattr.trip_rates_paths[6])
p8 = cb.DVector.load(HBattr.trip_rates_paths[8])

# %%
segs = ["p", "sic_2_digit"]
cb.Segmentation(cb.SegmentationInput(enum_segments=segs, naming_order=segs)).names

# %%
dvecs: list[cb.DVector] = []
for p in [p1, p2, p3, p4, p5, p6, p8]:
    p = p.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
    #dvecs.append(p.expand_to_other(p5, match_props=False))

# %%
p1.data # desired is by soc, trip rates by soc. Trip ends by soc bc. people by diff. soc have different trip rates. p3-p8 is not soc, 
# trip end from p3 to p8, only use emp. who work in these industries as a proxy for people working in these trip ends.
# p3 education, should get #students who go to prim/sec/uni as these are main source of attractions. we use #teachers/ professors as proxy 
# diff format of trip rates for 
p4.expand_to_other(p1, match_props=False).data

# %%
p4.data

# %%
emp = cb.DVector.load(r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf")
emp = cb.DVector(segmentation=emp.segmentation, import_data=emp.data, zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"))
emp = emp.translate_zoning(cb.ZoningSystem.get_zoning("normits"))

# %%
p1.zoning_system.name

# %%
p1 = p1.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p2 = p2.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p3 = p3.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p4 = p4.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p5 = p5.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p6 = p6.translate_zoning(cb.ZoningSystem.get_zoning("normits"))
p8 = p8.translate_zoning(cb.ZoningSystem.get_zoning("normits"))

# %%
emp.aggregate(["sic_2_digit", "soc"]).data

# %%
test1 = emp * p3
test2 = emp * p1

# %%
p1.data

# %%
test1.data.expand_to_other(test2, match_props=True).data

# %%
test2.data

# %%
dic = {1: test1, 2: test2}

# %%
cb.segmentation.SegmentsSuper("p").get_segment(subset=[1,2]).name

# %%
mylist = [None, "a", "q"]
list(map(lambda x: "p" if x is None else x, mylist))

# %%
new_list = list(map(lambda x: 0 if x is None else x, my_list))

# %%
cb.DVector.combine_from_dic(dic, cb.segmentation.SegmentsSuper("p").get_segment(subset=[1,2]), dic[1].segmentation, dic[1].zoning_system)

# %%
cb.ZoningSystem.get_zoning("gor")

# %%
c = a.expand_to_other(b, match_props=False)

# %%
c.data

# %%
a

# %%
cb.segments.SegmentsSuper("p").get_segment(subset=list([1,2,3]))

# %%
a = cb.DVector.load(HBattr.trip_rates_paths[4])
b = cb.DVector.load(HBattr.trip_rates_paths[3])

# %%
a.expand_to_other(b, match_props=True)

# %%
a.data

# %%
cb.Segment(name = "Purpose", values = {1: "test"}, alias="ppp")

# %%
cb.segmentation.SegmentsSuper("p").get_segment()

# %%
p = 8
trip_rate = cb.DVector.load(HBattr.trip_rates_paths[p])
trip_rate.data
#trip_rate = trip_rate.translate_zoning(cb.ZoningSystem.get_zoning(HBattr.export_paths._zoning_system),
#                                    check_totals=False, 
#                                    no_factors=True)

# %%
trip_rate = cb.DVector.load(HBattr.trip_rates_paths[p])
trip_rate.data

# %%
trip_rate.translate_zoning(cb.ZoningSystem.get_zoning(HBattr.export_paths._zoning_system),
                                    check_totals=False, 
                                    no_factors=True)

# %%
a = export_paths.asdf(
    trip_rates_paths={
        1: r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\hb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\hb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\hb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\hb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\hb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\hb_attraction_triprates_p8.dvec"
    },
    emp_landuse_path = r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf",
    hh_landuse_dir = r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs",
    hh_landuse_prefix = "Output P14.1")

# %%
export_paths.hb_attraction.__dict__

# %%
model = AttractionModel_TP(
    export_paths,
    trip_rates_paths={
        1: r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec",
        2: r"T:\ThomasPrince\hb_attraction_triprates_p2.dvec",
        3: r"T:\ThomasPrince\hb_attraction_triprates_p3.dvec",
        4: r"T:\ThomasPrince\hb_attraction_triprates_p4.dvec",
        5: r"T:\ThomasPrince\hb_attraction_triprates_p5.dvec",
        6: r"T:\ThomasPrince\hb_attraction_triprates_p6.dvec",
        8: r"T:\ThomasPrince\hb_attraction_triprates_p8.dvec"
    },
    emp_landuse_path = r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf",
    hh_landuse_dir = r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs",
    hh_landuse_prefix = "Output P14.1"
)

# %%
model.run()

# %%
# population data is P, 
a = {1: 5,
     2: 6,
     4: 7}

for i in a:
    print(a[i])

# %%
trip_rate = cb.DVector.load(model.trip_rates_path)

# %%
trip_rate.data

# %%
trip_rate.filter_segment_value("soc", [1]).data #- feel like purpose should be a segmentation, filtered like this...

# %%
trip_rate2 = trip_rate.translate_zoning(cb.ZoningSystem.get_zoning("normits"), check_totals=False,no_factors=True)

# %%
trip_rate2.data
#trip_rate.sum()

# %%
out_dict = {
            1: [],  # commuting
            2: [],  # e.business
            3: [85],  # education
            4: [46, 47],  # Shopping: retail
            5: [86, 64, 65, 66, 68, 69, 75, 77, 79, 80, 95, 96, 56],
            6: [90, 91, 92, 93, 94],  # Social
            7: [],  # visit friend
            8: [55, 2, 3]
        }

# %%
hh = cb.DVector.load(r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs\Output P13.3_NE.hdf")

# %%
hh.data

# %%
trip_rate.data

# %%
hh.

# %%
landuse = cb.DVector.load(model.landuse_path)

# %%
landuse.filter_segment_value("sic_2_digit", []).data

# %%
out_dict = {
            1: {'E01': 'All', 'exc': ['HH', '0-15', '16+']},  # commuting
            2: {'E01': 'All', 'exc': ['HH', '0-15', '16+']},  # e.business
            3: {'E03/04/05': 'S85'},  # 'Child': '0-15', 'Adult': '16+'},  # education
            4: {'E07': ['S46', 'S47']},  # shopping: retail
            # p.business: E08 (86/87) - health, E09 (64-69/75-81/95-96) - services, E11 (56) - food
            # 5: {'E08/09/11': ['S86', 'S87', 'S64', 'S65', 'S66', 'S68', 'S69', 'S75',
            #                   'S77', 'S79', 'S80', 'S81', 'S95', 'S96', 'S56']},
            5: {'E08': ['S86'],  # health
                'E09': ['S64', 'S65', 'S66', 'S68', 'S69', 'S75', 'S77', 'S79', 'S80', 'S95', 'S96'],
                'E11': ['S56']},
            6: {'E12': ['S90', 'S91', 'S92', 'S93', 'S94']},  # social
            7: {'E02': 'HH'},  # visit friends
            # holiday: E06 (55) - accommodation, E13 (S2-3) - fishing
            8: {'E06/13': ['S55', 'S02', 'S03']},
        }

# %%
landuse.data

# %%
trip_rate3 = trip_rate2.translate_zoning(cb.ZoningSystem.get_zoning("lsoa_2021"), check_totals=False, no_factors=True)

# %%
landuse2 = landuse.translate_zoning(cb.ZoningSystem.get_zoning("normits"), check_totals=False, no_factors=True)

# %%
landuse.aggregate(["soc"]) * trip_rate3

# %%
mts = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\NTS Processing DVec\outputs_is\attractions\hb\mode_time_splits\hb_mode_time_split_attraction_hb_fr.dvec")

# %%
mts.data

# %%
a = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP\Core\hb_attractions\hb_normits_pure_demand_2023_dvec.h5")

# %%
a.data

# %%
model.attraction_model_paths.export_paths.pure_demand[2023]

# %%
export_paths.hb_attraction.__dict__

# %%
a = ct.AttractionModelPaths_TP([2023], 
                           export_home=r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export",
                           report_home=r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP_test\Core\hb_attractions\reports",
                           zoning_system="normits",
                           _trip_origin="hb"
)

# %%
a.test

# %%
trip_rates_paths = {
    "p1": r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec"
}

# %%
landuse_paths = {
    "2023": r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf"
}

# %%
export_paths.nhb_attraction#.path_years

# %%
export_paths.hb_attraction._zoning_system

# %%
ct.AttractionModel_TP(**export_paths.hb_attraction.__dict__)

# %%
ct.AttractionModel(trip_rates_paths, landuse_paths, export_home="", zoning_system=cb.ZoningSystem.get_zoning("normits"))

# %%
export_paths.hb_attraction

# %%
model_paths = ct.TEMModelPaths(
    path_years=export_paths.path_years,
    export_home=,
    report_home=
)

# %%
export_paths.hb_attraction

# %%
def TP_generate_attraction(trip_rate_dvec, landuse_dvec):
    """
    Two Inputs: 
        1. Trip Rates Path
        2. Land Use Path
    """
    #trip_rate_dvec = cb.DVector.load(trip_rates_path)
    #landuse_dvec = cb.DVector.load(landuse_path)

    attr = trip_rate_dvec * landuse_dvec
    
    return attr
    

    """
        Applies trip rates to the given HB employment.

        Parameters
        ----------
        emp_dvec:
            Dvector containing the employment.

        Returns
        -------
        pure_attraction:
            Returns the product of employment and attraction trip rate Dvector.
            ie., pure attraction
        

        # Define the zoning and segmentations we want to use
        
        attr_dict = {}
        segs = []
        longest = []
        # Different purposes have different segmentations
        for purpose, path in self.trip_rates_paths.items():
            trip_rate = cb.DVector.load(path)
            landuse = cb.DVector.load[self.landuse_paths[purpose]]
            attr = landuse * trip_rate
            for seg in attr.segmentation.names:
                if seg not in segs:
                    segs.append(seg)
            attr_dict[purpose] = attr
            if len(attr) > len(longest):
                longest = attr
        for purpose, dvec in attr_dict.items():
            if dvec == longest:
                continue
            attr_dict[purpose] = dvec.expand_to_other(longest, match_props=True)
        purp_seg = cb.segments.SegmentsSuper("p").get_segment(
            subset=list(attr_dict.keys())
        )
        zone_system = longest.zone_system
        attr_dvec = cb.DVector.combine_from_dic(attr_dict, purp_seg, zone_system)

        return attr_dvec
        """

# %%
trip_rates_path = Path(r"T:\ThomasPrince\hb_attraction_triprates_p1.dvec")
landuse_path = Path(r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf")

#TP_generate_attraction(trip_rates_path, landuse_path)

# %%
trip_rate_dvec = cb.DVector.load(trip_rates_path)
landuse_dvec = cb.DVector.load(landuse_path)

landuse_dvec = cb.DVector(segmentation=landuse_dvec.segmentation, import_data=landuse_dvec.data,zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"))

# %%
trip_rate_dvec = trip_rate_dvec.translate_zoning(cb.ZoningSystem.get_zoning("normits"), check_totals=False, no_factors=True)
landuse_dvec = landuse_dvec.translate_zoning(cb.ZoningSystem.get_zoning("normits"), check_totals=False, no_factors=True)

# %%
attr = trip_rate_dvec * landuse_dvec

# %%
attr.data

# %%
trip_rate_dvec.data

# %%
landuse_dvec.data

# %%
attr.aggregate(["soc", "sic_2_digit"]).data

# %%
(landuse_dvec.aggregate(["soc", "sic_2_digit"]) * trip_rate_dvec).data

# %%
trip_rate_dvec.data

# %%
landuse_dvec.translate_zoning()

# %%
TP_generate_attraction(trip_rate_dvec, landuse_dvec)

# %%
trip_rate_dvec.zoning_system.name

# %%
cb.DVector(segmentation=landuse_dvec.segmentation, import_data=landuse_dvec.data,zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"))

# %%
landuse_dvec.data#zoning_system.name

# %%
landuse_dvec.translate_zoning(cb.ZoningSystem.get_zoning("normits"))

# %%
trip_rate_dvec.zoning_system.name

# %%
landuse_dvec.translate_zoning(cb.ZoningSystem.get_zoning("normits"))

# %%
dir = r"T:\ThomasPrince"
triprates_paths = {
    "": dir 
}

# %%
TEM_Paths = ct.TEMModelPaths(
    path_years=[2023],
    export_home=r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export",
    report_home=r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Reports",
    zoning_system="normits"
)

# %%
HB_Attr_TEM_Paths = ct.AttractionModelPaths(
    "hb",
    TEM_Paths.path_years, 
    TEM_Paths.export_home,
    TEM_Paths.report_home,
    TEM_Paths._zoning_system
)

# %%
a = ct.Scenarios("Core")

# %%
ct.TEMExportPaths(
        path_years=[2023],
        scenario=a,
        iteration_name="iter1",
        export_home=pathlib.Path(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export")
)

# %%
ct.attraction_models

# %%
HB_TEM_Paths

# %%
ct.inputs.AttractionModelPaths(HB_TEM_Paths)

# %%
ct.inputs.AttrInput(
    triprates={}, # dict[str, os.PathLike] # purpose: path, goes to directory, reads in purpose for each one.
    landuse={"2023": r"F:\Deliverables\Land-Use\241213_Employment\02_Final Outputs\Output E6.hdf"}, # dict[str, os.PathLike] # year: directory, within dir have emp, household, etc., download lu and same folder.
    balance_paths={}, # dict[str, os.PathLike] # might be obsolete - attractions balanced to prods.
    balance_zoning=cb.BalancingZones()# cb.BalancingZones
)

# %%
emp_landuse = cb.DVector.load(HBAttr.emp_landuse_paths[2023])
emp_landuse = cb.DVector(segmentation=emp_landuse.segmentation, import_data=emp_landuse.data, zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"))
desired_zoning = cb.ZoningSystem.get_zoning(HBAttr.export_paths._zoning_system)
#emp_landuse = emp_landuse.translate_zoning(desired_zoning, check_totals=False, no_factors=True)

# %%
emp_landuse.save(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Land Use\employment\Output E6.hdf")

# %%
HBAttr.emp_landuse_paths[2023]

# %%
emp_landuse = cb.DVector.load(HBAttr.emp_landuse_paths[2023])

# %%
emp_landuse.zoning_system.name

# %%
import pathlib

# %%
dvecs: list[cb.DVector] = []
for region in [
    "EM",
    "EoE",
    "Lon",
    "NE",
    "NW",
    "SE",
    "SW",
    "Wales",
    "WM",
    "YH",
    "Scotland"
]:
    
    dvec = cb.DVector.load(
            pathlib.Path(HBAttr.hh_landuse_dirs[2023])
            / f"{HBAttr.hh_landuse_prefix}_{region}.hdf"
        )
    
    #dvecs.append(
    #    cb.DVector.load(
    #        pathlib.Path(HBAttr.hh_landuse_dirs[2023])
    #        / f"{HBAttr.hh_landuse_prefix}_{region}.hdf"
    #    )
    #)  # .aggregate(SEG_HH)) # I don't know what SEG_HH should be
    dvec_out = cb.DVector(
        import_data=dvec.data,
        segmentation=dvec.segmentation,
        zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"),
    )  # I don't know what TT_HH should be - TT defined in utils? assuming it's TT from utils - changed segmentation to be the same as the first dvec read
    #dvec_out = dvec_out.translate_zoning(
    #    cb.ZoningSystem.get_zoning(HBAttr.export_paths._zoning_system)
    #)
    dvec_out.save(rf"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Land Use\population\{HBAttr.hh_landuse_prefix}_{region}.hdf")


#data = pd.concat([d.data for d in dvecs], axis=1)
#hh_landuse = cb.DVector(
#    import_data=data,
#    segmentation=dvecs[0].segmentation,
#    zoning_system=cb.ZoningSystem.get_zoning("lsoa_2021"),
#)  # I don't know what TT_HH should be - TT defined in utils? assuming it's TT from utils - changed segmentation to be the same as the first dvec read
#hh_landuse = hh_landuse.translate_zoning(
#    cb.ZoningSystem.get_zoning(HBAttr.export_paths._zoning_system)
#)

# %%
emp_landuse.save(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Land Use\employment\Output E6.hdf")

# %%
dvec_out.data

# %%
dvec_out.data.columns.name #zoning_system.name

# %%
pop = cb.DVector.load(r"F:\Deliverables\Land-Use\241220_Populationv2\02_Final Outputs\Output P11_EM.hdf")

# %%
pop.data# ["age_9", "g", "ns_sec", "soc", "pop_emp", "adults", "adult_nssec", "car_availability"]

# %%
pop2 = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\(normitsefs) Transfer\TP_20250128-copy\tem_inputs\pop_2023.dvec")

# %%
pop2.data

# %%
trip_rate = cb.DVector.load(HBAttr.trip_rates_paths[1])
trip_rate_ = trip_rate.translate_zoning(
            cb.ZoningSystem.get_zoning(HBAttr.export_paths._zoning_system),
            check_totals=False,
            no_factors=True,
        )

# %%
trip_rate.data

# %%
trip_rate_.data

# %%
prod = cb.DVector.load(r"C:\Users\Spiral\Documents\Thomas Prince\Common Analytical Framework\NoTEM\Export\TP_v3\Core\hb_productions\hb_normits_tem_segmented_2023_dvec.h5")

# %%
prod.data
